# %%
data <- read.csv(file="C:\\Users\\ACER\\Downloads\\winequality-red.csv",header=FALSE,sep=';')
x<-data[11]
X<-as.numeric(unlist(x, use.names=FALSE))
X
# Out:
#    [1]  9.400000  9.800000  9.800000  9.800000  9.400000  9.400000  9.400000
#    [8] 10.000000  9.500000 10.500000  9.200000 10.500000  9.900000  9.100000
#   [15]  9.200000  9.200000 10.500000  9.300000  9.000000  9.200000  9.400000
#   [22]  9.700000  9.500000  9.400000  9.700000  9.300000  9.500000  9.500000
#   [29]  9.400000  9.800000 10.100000 10.600000  9.800000  9.400000  9.200000
#   [36]  9.600000 10.800000  9.700000  9.800000 10.500000 10.500000  9.300000
#   [43] 10.500000 10.300000  9.500000 13.100000  9.200000  9.500000  9.200000
#   [50]  9.200000  9.200000  9.400000  9.400000  9.400000 10.200000  9.500000
#   [57]  9.600000  9.400000 10.000000  9.400000  9.200000  9.300000  9.500000
#   [64]  9.800000 10.900000 10.900000  9.600000 10.700000 10.700000 10.500000
#   [71]  9.500000  9.500000  9.500000  9.200000  9.600000 10.500000 10.500000
#   [78] 10.700000 10.100000  9.100000  9.200000  9.400000  9.100000  9.400000
# ...

# %%
y<-data[10]
Y<-as.numeric(unlist(y,use.names=FALSE))
Y
# Out:
#    [1] 0.56 0.68 0.65 0.58 0.56 0.56 0.46 0.47 0.57 0.80 0.54 0.80 0.52 1.56
#   [15] 0.88 0.93 0.75 1.28 0.50 1.08 0.53 0.65 0.91 0.53 0.63 0.56 0.59 0.91
#   [29] 0.55 0.59 0.54 0.57 0.66 0.52 0.55 0.55 0.60 0.73 0.48 0.83 0.83 0.51
#   [43] 0.90 1.20 0.52 0.56 0.73 0.58 0.56 0.58 0.74 0.63 0.64 0.56 0.63 0.53
#   [57] 0.63 0.77 0.59 0.54 0.64 0.71 0.62 0.57 0.39 0.39 0.58 0.58 0.79 0.95
#   [71] 0.54 0.48 0.48 0.53 0.82 0.66 0.66 0.55 0.52 1.12 0.56 1.28 0.57 1.14
#   [85] 0.78 0.59 1.95 0.64 1.22 0.53 0.54 1.95 1.98 0.64 0.48 0.60 0.56 0.63
#   [99] 0.56 0.59 0.61 0.56 0.59 0.51 0.48 0.51 1.31 0.79 0.80 0.69 0.93 0.66
#  [113] 0.66 0.67 0.93 0.63 0.61 0.50 0.60 0.54 0.57 0.60 0.52 0.53 0.48 0.70
#  [127] 0.49 0.48 0.92 0.57 0.66 0.63 0.63 0.58 0.55 0.82 0.77 0.64 0.54 0.54
#  [141] 0.82 0.77 0.79 0.58 0.79 0.62 0.52 0.80 0.58 0.61 0.53 2.00 0.54 0.54
#  [155] 0.72 0.71 0.72 0.71 0.50 0.57 0.56 1.08 0.56 0.49 0.49 0.62 0.52 0.48
# ...

# %%
relation<-lm(Y~X)
relation
# Out:
# Call:
# lm(formula = Y ~ X)
#
# Coefficients:
# (Intercept)            X
#     0.50298      0.01489

# %%
#make a plot
plot(X,Y,col = "black",abline(relation,col='red'),xlab="Zawartość alkoholu",ylab="Zawartość siarczanów",main="Regresja liniowa")
# Out:
# Plot with title "Regresja liniowa"
